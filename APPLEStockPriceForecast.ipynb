# %% [markdown]
# <a href="https://colab.research.google.com/github/dan2380/StockPrediction/blob/main/APPLEStockPriceForecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dataset from https://finance.yahoo.com/quote/2357.TW/history?p=2357.TW
#dataset from https://finance.yahoo.com/quote/AAPL/history?period1=345427200&period2=1676592000&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true
#adjusted time period to : max

# %%
import pandas as pd
df = pd.read_csv('AAPL.csv')
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...           ...         ...         ...         ...         ...         ...
# 10630  2023-02-10  149.460007  151.339996  149.220001  151.009995  151.009995
# 10631  2023-02-13  150.949997  154.259995  150.919998  153.850006  153.850006
# 10632  2023-02-14  152.119995  153.770004  150.860001  153.199997  153.199997
# 10633  2023-02-15  153.110001  155.500000  152.880005  155.330002  155.330002
# 10634  2023-02-16  153.509995  156.330002  153.350006  153.710007  153.710007
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 10630   57409100
# 10631   62199000
# 10632   61707600
# 10633   65669300
# 10634   68167900
#
# [10635 rows x 7 columns]

# %%
#We will discard all info except for date and closing data
df = df[['Date', 'Close']]
df
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10630  2023-02-10  151.009995
# 10631  2023-02-13  153.850006
# 10632  2023-02-14  153.199997
# 10633  2023-02-15  155.330002
# 10634  2023-02-16  153.710007
#
# [10635 rows x 2 columns]

# %%
#import datetime
import datetime

# %%
#convert datetime str obj to datetime obj
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0       1980-12-12
# 1       1980-12-15
# 2       1980-12-16
# 3       1980-12-17
# 4       1980-12-18
#            ...
# 10630   2023-02-10
# 10631   2023-02-13
# 10632   2023-02-14
# 10633   2023-02-15
# 10634   2023-02-16
# Name: Date, Length: 10635, dtype: datetime64[ns]

# %%
#we see at the bottom that dtype is now changed to a datetime object, which is good
#we will now remove the default index, and make the Date the index instead
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-02-10  151.009995
# 2023-02-13  153.850006
# 2023-02-14  153.199997
# 2023-02-15  155.330002
# 2023-02-16  153.710007
#
# [10635 rows x 1 columns]

# %%
#plot out life time graph of Apple's closing stock price
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
#supervised learning
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = pd.to_datetime(first_date_str)
  last_date  = pd.to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day of first time: '1980-12-17'
# Start day second time around: '2021-02-17'
windowed_df = df_to_windowed_df(df, 
                                '2022-02-17', 
                                '2023-02-16', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-02-17  168.880005  172.789993  172.550003  168.880005
# 1    2022-02-18  172.789993  172.550003  168.880005  167.300003
# 2    2022-02-22  172.550003  168.880005  167.300003  164.320007
# 3    2022-02-23  168.880005  167.300003  164.320007  160.070007
# 4    2022-02-24  167.300003  164.320007  160.070007  162.740005
# ..          ...         ...         ...         ...         ...
# 246  2023-02-10  154.649994  151.919998  150.869995  151.009995
# 247  2023-02-13  151.919998  150.869995  151.009995  153.850006
# 248  2023-02-14  150.869995  151.009995  153.850006  153.199997
# 249  2023-02-15  151.009995  153.850006  153.199997  155.330002
# 250  2023-02-16  153.850006  153.199997  155.330002  153.710007
#
# [251 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((251,), (251, 3, 1), (251,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 98ms/step - loss: 23697.6797 - mean_absolute_error: 153.5139 - val_loss: 17942.5684 - val_mean_absolute_error: 133.7787
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - loss: 23493.4531 - mean_absolute_error: 152.8481 - val_loss: 17757.9258 - val_mean_absolute_error: 133.0867
# Epoch 3/100
# 7/7 [==============================] - 0s 12ms/step - loss: 23274.8281 - mean_absolute_error: 152.1298 - val_loss: 17546.4375 - val_mean_absolute_error: 132.2898
# Epoch 4/100
# 7/7 [==============================] - 0s 14ms/step - loss: 23016.2754 - mean_absolute_error: 151.2776 - val_loss: 17302.7969 - val_mean_absolute_error: 131.3659
# Epoch 5/100
# 7/7 [==============================] - 0s 13ms/step - loss: 22726.4316 - mean_absolute_error: 150.3174 - val_loss: 17037.9551 - val_mean_absolute_error: 130.3538
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 22407.5918 - mean_absolute_error: 149.2521 - val_loss: 16717.7754 - val_mean_absolute_error: 129.1195
# Epoch 7/100
# 7/7 [==============================] - 0s 11ms/step - loss: 21999.3398 - mean_absolute_error: 147.8788 - val_loss: 16296.3467 - val_mean_absolute_error: 127.4771
# Epoch 8/100
# 7/7 [==============================] - 0s 11ms/step - loss: 21479.3223 - mean_absolute_error: 146.1081 - val_loss: 15790.9492 - val_mean_absolute_error: 125.4786
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 20853.7520 - mean_absolute_error: 143.9490 - val_loss: 15140.3027 - val_mean_absolute_error: 122.8573
# Epoch 10/100
# 7/7 [==============================] - 0s 11ms/step - loss: 20020.5781 - mean_absolute_error: 141.0281 - val_loss: 14250.8311 - val_mean_absolute_error: 119.1820
# Epoch 11/100
# 7/7 [==============================] - 0s 11ms/step - loss: 18905.3301 - mean_absolute_error: 137.0099 - val_loss: 13284.8525 - val_mean_absolute_error: 115.0608
# Epoch 12/100
# 7/7 [==============================] - 0s 14ms/step - loss: 17791.6797 - mean_absolute_error: 132.8851 - val_loss: 12356.1133 - val_mean_absolute_error: 110.9510
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 16666.0352 - mean_absolute_error: 128.5802 - val_loss: 11316.1201 - val_mean_absolute_error: 106.1599
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 15377.1846 - mean_absolute_error: 123.4732 - val_loss: 10108.7373 - val_mean_absolute_error: 100.3111
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 13875.5684 - mean_absolute_error: 117.2269 - val_loss: 8788.5469 - val_mean_absolute_error: 93.5011
# Epoch 16/100
# 7/7 [==============================] - 0s 14ms/step - loss: 12278.1016 - mean_absolute_error: 110.2018 - val_loss: 7517.1270 - val_mean_absolute_error: 86.4365
# Epoch 17/100
# 7/7 [==============================] - 0s 12ms/step - loss: 10735.8613 - mean_absolute_error: 102.9701 - val_loss: 6238.0249 - val_mean_absolute_error: 78.6857
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 9125.2852 - mean_absolute_error: 94.7692 - val_loss: 4805.1978 - val_mean_absolute_error: 68.9748
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7245.3979 - mean_absolute_error: 84.3449 - val_loss: 3370.2793 - val_mean_absolute_error: 57.6538
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 5469.6499 - mean_absolute_error: 72.9878 - val_loss: 2229.5210 - val_mean_absolute_error: 46.7217
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3969.8601 - mean_absolute_error: 61.8366 - val_loss: 1299.1541 - val_mean_absolute_error: 35.3952
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2703.4099 - mean_absolute_error: 50.6045 - val_loss: 620.3712 - val_mean_absolute_error: 23.9451
# Epoch 23/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1679.8022 - mean_absolute_error: 39.0972 - val_loss: 204.4715 - val_mean_absolute_error: 12.5809
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 932.0422 - mean_absolute_error: 28.0903 - val_loss: 53.3562 - val_mean_absolute_error: 5.6762
# Epoch 25/100
# 7/7 [==============================] - 0s 13ms/step - loss: 487.7620 - mean_absolute_error: 18.9021 - val_loss: 81.2224 - val_mean_absolute_error: 7.8464
# Epoch 26/100
# 7/7 [==============================] - 0s 11ms/step - loss: 248.8092 - mean_absolute_error: 12.6111 - val_loss: 213.3932 - val_mean_absolute_error: 12.8953
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 158.9866 - mean_absolute_error: 10.2870 - val_loss: 395.6454 - val_mean_absolute_error: 18.6885
# Epoch 28/100
# 7/7 [==============================] - 0s 14ms/step - loss: 133.2202 - mean_absolute_error: 9.7471 - val_loss: 479.8977 - val_mean_absolute_error: 20.8307
# Epoch 29/100
# 7/7 [==============================] - 0s 13ms/step - loss: 134.0603 - mean_absolute_error: 9.8509 - val_loss: 495.3102 - val_mean_absolute_error: 21.2029
# Epoch 30/100
# 7/7 [==============================] - 0s 11ms/step - loss: 134.3235 - mean_absolute_error: 9.8608 - val_loss: 475.7424 - val_mean_absolute_error: 20.7409
# Epoch 31/100
# 7/7 [==============================] - 0s 11ms/step - loss: 132.0682 - mean_absolute_error: 9.7593 - val_loss: 436.2342 - val_mean_absolute_error: 19.7796
# Epoch 32/100
# 7/7 [==============================] - 0s 13ms/step - loss: 129.6247 - mean_absolute_error: 9.6152 - val_loss: 405.1333 - val_mean_absolute_error: 18.9679
# Epoch 33/100
# 7/7 [==============================] - 0s 11ms/step - loss: 129.6862 - mean_absolute_error: 9.5961 - val_loss: 411.2164 - val_mean_absolute_error: 19.1361
# Epoch 34/100
# 7/7 [==============================] - 0s 14ms/step - loss: 129.1752 - mean_absolute_error: 9.5965 - val_loss: 419.2711 - val_mean_absolute_error: 19.3488
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 129.2012 - mean_absolute_error: 9.6069 - val_loss: 421.8852 - val_mean_absolute_error: 19.4182
# Epoch 36/100
# 7/7 [==============================] - 0s 11ms/step - loss: 128.9007 - mean_absolute_error: 9.5953 - val_loss: 418.6382 - val_mean_absolute_error: 19.3350
# Epoch 37/100
# 7/7 [==============================] - 0s 11ms/step - loss: 128.7372 - mean_absolute_error: 9.5954 - val_loss: 426.0000 - val_mean_absolute_error: 19.5280
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 128.3900 - mean_absolute_error: 9.5757 - val_loss: 411.8151 - val_mean_absolute_error: 19.1660
# Epoch 39/100
# 7/7 [==============================] - 0s 14ms/step - loss: 128.1823 - mean_absolute_error: 9.5724 - val_loss: 418.4771 - val_mean_absolute_error: 19.3447
# Epoch 40/100
# 7/7 [==============================] - 0s 13ms/step - loss: 127.1178 - mean_absolute_error: 9.5196 - val_loss: 403.2430 - val_mean_absolute_error: 18.9449
# Epoch 41/100
# 7/7 [==============================] - 0s 12ms/step - loss: 127.1408 - mean_absolute_error: 9.5064 - val_loss: 400.1019 - val_mean_absolute_error: 18.8654
# Epoch 42/100
# 7/7 [==============================] - 0s 11ms/step - loss: 126.5814 - mean_absolute_error: 9.4900 - val_loss: 405.6792 - val_mean_absolute_error: 19.0198
# Epoch 43/100
# 7/7 [==============================] - 0s 12ms/step - loss: 126.3100 - mean_absolute_error: 9.4957 - val_loss: 404.2259 - val_mean_absolute_error: 18.9869
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 125.4354 - mean_absolute_error: 9.4503 - val_loss: 388.1466 - val_mean_absolute_error: 18.5734
# Epoch 45/100
# 7/7 [==============================] - 0s 12ms/step - loss: 124.5051 - mean_absolute_error: 9.3901 - val_loss: 354.6218 - val_mean_absolute_error: 17.7721
# Epoch 46/100
# 7/7 [==============================] - 0s 15ms/step - loss: 110.0668 - mean_absolute_error: 8.6741 - val_loss: 295.8408 - val_mean_absolute_error: 16.1516
# Epoch 47/100
# 7/7 [==============================] - 0s 12ms/step - loss: 116.7232 - mean_absolute_error: 9.0937 - val_loss: 322.8521 - val_mean_absolute_error: 16.9902
# Epoch 48/100
# 7/7 [==============================] - 0s 12ms/step - loss: 109.5107 - mean_absolute_error: 8.6401 - val_loss: 276.2603 - val_mean_absolute_error: 15.7119
# Epoch 49/100
# 7/7 [==============================] - 0s 12ms/step - loss: 107.3253 - mean_absolute_error: 8.7011 - val_loss: 286.9464 - val_mean_absolute_error: 15.9423
# Epoch 50/100
# 7/7 [==============================] - 0s 14ms/step - loss: 100.2909 - mean_absolute_error: 8.3899 - val_loss: 233.5531 - val_mean_absolute_error: 14.2971
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 94.8743 - mean_absolute_error: 7.9174 - val_loss: 262.5202 - val_mean_absolute_error: 15.3344
# Epoch 52/100
# 7/7 [==============================] - 0s 15ms/step - loss: 90.5501 - mean_absolute_error: 8.0263 - val_loss: 213.8280 - val_mean_absolute_error: 13.5966
# Epoch 53/100
# 7/7 [==============================] - 0s 12ms/step - loss: 81.4312 - mean_absolute_error: 7.3294 - val_loss: 250.2015 - val_mean_absolute_error: 15.0018
# Epoch 54/100
# 7/7 [==============================] - 0s 12ms/step - loss: 81.0858 - mean_absolute_error: 7.4944 - val_loss: 172.4868 - val_mean_absolute_error: 12.2477
# Epoch 55/100
# 7/7 [==============================] - 0s 11ms/step - loss: 70.6251 - mean_absolute_error: 6.9459 - val_loss: 145.8494 - val_mean_absolute_error: 11.1131
# Epoch 56/100
# 7/7 [==============================] - 0s 12ms/step - loss: 68.9850 - mean_absolute_error: 6.7603 - val_loss: 132.1492 - val_mean_absolute_error: 10.6566
# Epoch 57/100
# 7/7 [==============================] - 0s 11ms/step - loss: 65.5929 - mean_absolute_error: 6.5427 - val_loss: 144.9495 - val_mean_absolute_error: 11.2295
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 57.9060 - mean_absolute_error: 6.1412 - val_loss: 114.4040 - val_mean_absolute_error: 9.8800
# Epoch 59/100
# 7/7 [==============================] - 0s 11ms/step - loss: 54.5869 - mean_absolute_error: 5.9855 - val_loss: 88.7199 - val_mean_absolute_error: 8.5782
# Epoch 60/100
# 7/7 [==============================] - 0s 12ms/step - loss: 51.9369 - mean_absolute_error: 5.9049 - val_loss: 72.2164 - val_mean_absolute_error: 7.4763
# Epoch 61/100
# 7/7 [==============================] - 0s 12ms/step - loss: 53.4299 - mean_absolute_error: 5.9589 - val_loss: 152.0564 - val_mean_absolute_error: 11.8513
# Epoch 62/100
# 7/7 [==============================] - 0s 20ms/step - loss: 48.7257 - mean_absolute_error: 5.6596 - val_loss: 86.4373 - val_mean_absolute_error: 8.6350
# Epoch 63/100
# 7/7 [==============================] - 0s 18ms/step - loss: 44.2226 - mean_absolute_error: 5.4191 - val_loss: 75.3017 - val_mean_absolute_error: 7.9540
# Epoch 64/100
# 7/7 [==============================] - 0s 17ms/step - loss: 39.0962 - mean_absolute_error: 5.1177 - val_loss: 47.8535 - val_mean_absolute_error: 6.0602
# Epoch 65/100
# 7/7 [==============================] - 0s 19ms/step - loss: 37.4362 - mean_absolute_error: 4.9012 - val_loss: 59.1384 - val_mean_absolute_error: 7.0794
# Epoch 66/100
# 7/7 [==============================] - 0s 20ms/step - loss: 32.7998 - mean_absolute_error: 4.5653 - val_loss: 54.7210 - val_mean_absolute_error: 6.7721
# Epoch 67/100
# 7/7 [==============================] - 0s 20ms/step - loss: 30.8788 - mean_absolute_error: 4.4202 - val_loss: 20.5197 - val_mean_absolute_error: 3.8064
# Epoch 68/100
# 7/7 [==============================] - 0s 18ms/step - loss: 33.7336 - mean_absolute_error: 4.6738 - val_loss: 38.7646 - val_mean_absolute_error: 5.4980
# Epoch 69/100
# 7/7 [==============================] - 0s 16ms/step - loss: 29.3052 - mean_absolute_error: 4.2488 - val_loss: 52.3213 - val_mean_absolute_error: 6.6801
# Epoch 70/100
# 7/7 [==============================] - 0s 17ms/step - loss: 25.7154 - mean_absolute_error: 3.9450 - val_loss: 76.4745 - val_mean_absolute_error: 8.3275
# Epoch 71/100
# 7/7 [==============================] - 0s 15ms/step - loss: 30.4267 - mean_absolute_error: 4.5066 - val_loss: 36.3337 - val_mean_absolute_error: 5.3777
# Epoch 72/100
# 7/7 [==============================] - 0s 21ms/step - loss: 28.1736 - mean_absolute_error: 4.3070 - val_loss: 13.7436 - val_mean_absolute_error: 3.1037
# Epoch 73/100
# 7/7 [==============================] - 0s 18ms/step - loss: 28.5627 - mean_absolute_error: 4.3190 - val_loss: 37.8938 - val_mean_absolute_error: 5.5290
# Epoch 74/100
# 7/7 [==============================] - 0s 16ms/step - loss: 20.7069 - mean_absolute_error: 3.6497 - val_loss: 23.1719 - val_mean_absolute_error: 4.0925
# Epoch 75/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.3275 - mean_absolute_error: 3.5400 - val_loss: 12.6700 - val_mean_absolute_error: 2.9149
# Epoch 76/100
# 7/7 [==============================] - 0s 20ms/step - loss: 18.4604 - mean_absolute_error: 3.4421 - val_loss: 41.8630 - val_mean_absolute_error: 5.9509
# Epoch 77/100
# 7/7 [==============================] - 0s 20ms/step - loss: 21.3749 - mean_absolute_error: 3.6240 - val_loss: 15.7412 - val_mean_absolute_error: 3.2611
# Epoch 78/100
# 7/7 [==============================] - 0s 18ms/step - loss: 17.5552 - mean_absolute_error: 3.3749 - val_loss: 14.1430 - val_mean_absolute_error: 3.0887
# Epoch 79/100
# 7/7 [==============================] - 0s 18ms/step - loss: 16.6903 - mean_absolute_error: 3.2981 - val_loss: 6.6648 - val_mean_absolute_error: 2.0653
# Epoch 80/100
# 7/7 [==============================] - 0s 23ms/step - loss: 19.3132 - mean_absolute_error: 3.5874 - val_loss: 13.0602 - val_mean_absolute_error: 2.9619
# Epoch 81/100
# 7/7 [==============================] - 0s 18ms/step - loss: 16.6539 - mean_absolute_error: 3.3115 - val_loss: 10.8631 - val_mean_absolute_error: 2.7196
# Epoch 82/100
# 7/7 [==============================] - 0s 21ms/step - loss: 16.8701 - mean_absolute_error: 3.2764 - val_loss: 12.3049 - val_mean_absolute_error: 2.8850
# Epoch 83/100
# 7/7 [==============================] - 0s 21ms/step - loss: 15.4678 - mean_absolute_error: 3.1962 - val_loss: 13.0873 - val_mean_absolute_error: 2.9642
# Epoch 84/100
# 7/7 [==============================] - 0s 16ms/step - loss: 15.3238 - mean_absolute_error: 3.1595 - val_loss: 9.6517 - val_mean_absolute_error: 2.5566
# Epoch 85/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.0292 - mean_absolute_error: 3.1376 - val_loss: 20.7440 - val_mean_absolute_error: 3.7958
# Epoch 86/100
# 7/7 [==============================] - 0s 14ms/step - loss: 15.0938 - mean_absolute_error: 3.1425 - val_loss: 14.7160 - val_mean_absolute_error: 3.1297
# Epoch 87/100
# 7/7 [==============================] - 0s 13ms/step - loss: 17.1588 - mean_absolute_error: 3.3069 - val_loss: 14.8931 - val_mean_absolute_error: 3.1589
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 14.5258 - mean_absolute_error: 3.0711 - val_loss: 8.6893 - val_mean_absolute_error: 2.4271
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 15.4464 - mean_absolute_error: 3.1356 - val_loss: 21.1384 - val_mean_absolute_error: 3.8378
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 15.5350 - mean_absolute_error: 3.2545 - val_loss: 10.0864 - val_mean_absolute_error: 2.6279
# Epoch 91/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14.5008 - mean_absolute_error: 3.1142 - val_loss: 18.1939 - val_mean_absolute_error: 3.5191
# Epoch 92/100
# 7/7 [==============================] - 0s 14ms/step - loss: 14.5349 - mean_absolute_error: 3.0494 - val_loss: 15.6216 - val_mean_absolute_error: 3.2265
# Epoch 93/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14.3830 - mean_absolute_error: 3.0336 - val_loss: 13.7061 - val_mean_absolute_error: 3.0272
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 13.3566 - mean_absolute_error: 2.9114 - val_loss: 6.3401 - val_mean_absolute_error: 2.0011
# Epoch 95/100
# 7/7 [==============================] - 0s 11ms/step - loss: 16.2513 - mean_absolute_error: 3.1979 - val_loss: 8.4332 - val_mean_absolute_error: 2.3889
# Epoch 96/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14.8021 - mean_absolute_error: 3.1231 - val_loss: 22.9979 - val_mean_absolute_error: 4.0779
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 15.0142 - mean_absolute_error: 3.0631 - val_loss: 18.3727 - val_mean_absolute_error: 3.5313
# Epoch 98/100
# 7/7 [==============================] - 0s 12ms/step - loss: 14.5828 - mean_absolute_error: 3.0262 - val_loss: 11.2469 - val_mean_absolute_error: 2.7757
# Epoch 99/100
# 7/7 [==============================] - 0s 12ms/step - loss: 13.6822 - mean_absolute_error: 2.9639 - val_loss: 8.5091 - val_mean_absolute_error: 2.4082
# Epoch 100/100
# 7/7 [==============================] - 0s 12ms/step - loss: 14.0004 - mean_absolute_error: 3.0177 - val_loss: 12.5765 - val_mean_absolute_error: 2.9241

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
